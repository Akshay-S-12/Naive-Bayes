# %%
import sys
import time

print("Python executable:", sys.executable)
print("Python version:", sys.version)

# Simple test loop
for i in range(3):
    print(f"Test {i+1}")
    time.sleep(0.5)

print("Kernel is running fine!")
